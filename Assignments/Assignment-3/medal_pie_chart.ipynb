# %%
#Ama Agadzi- 100449923

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [46,38,29,24,13,11,11,8,8,7,107]
label_list= ["USA", "CHN","GBR","RUS","KOR","GER","FRA","ITA","HUN","AUS","OTHER"]

plt.axis("equal")
plt.pie(x,labels= label_list)
plt.title("2012 Olympic gold medals (100449923)")
plt.show()
